# %%
import pickle
import matplotlib.pyplot as plt

# %%
comp_file = "comparison_nums.pk"
infile = open(comp_file,'rb')
losses, l2, mse, me = pickle.load(infile)
infile.close()

# %%
print(len(losses))
# Out:
# 940

# %%
plt.clf()
plt.figure(figsize=(16, 8))
plt.plot(losses)
plt.show()
